# %% [markdown]
# #Link LinkedIn
# https://www.linkedin.com/in/diego-alejandro-irreno-torres-a64836208/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Certificado

# %% [markdown]
# ![image.png](data:image/png;base64,...)
